# %%
# Two hidden Layers
from __future__ import print_function
import numpy as np
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers.core import Dense, Activation
from keras.optimizers import SGD
from keras.utils import np_utils
np.random.seed(1671) # for reproducibility
# network and training
NB_EPOCH = 20
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10 # number of outputs = number of digits
OPTIMIZER = SGD() # optimizer, explained later in this chapter
N_HIDDEN = 128
VALIDATION_SPLIT = 0.2 #how much TRAIN is reserved for VALIDATION
# data: shuffled and split between train and test sets
(X_train, y_train), (X_test, y_test) = mnist.load_data()
#X_train is 60000 rows of 28x28 values --> reshaped in 60000 x 784
RESHAPED = 784
#
X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
# normalize
X_train /= 255
X_test /= 255
print (X_train.shape[0], 'train samples')
print (X_test.shape[0], 'test samples')
# convert class vectors to binary class matrices
Y_train = np_utils.to_categorical(y_train, NB_CLASSES)
Y_test = np_utils.to_categorical(y_test, NB_CLASSES)
# M_HIDDEN hidden layers
# 10 outputs
# final stage is softmax
model = Sequential()
model.add(Dense(N_HIDDEN, input_shape=(RESHAPED,)))
model.add(Activation('relu'))
model.add(Dense(NB_CLASSES))
model.add(Activation('relu'))
model.add(Dense(NB_CLASSES))
model.add(Activation('softmax'))
model.summary()
model.compile(loss='categorical_crossentropy', 
             optimizer=OPTIMIZER,
             metrics=['accuracy'])
history = model.fit(X_train, Y_train,
                   batch_size=BATCH_SIZE, epochs=NB_EPOCH,
                   verbose=VERBOSE, validation_split=VALIDATION_SPLIT)
score = model.evaluate(X_test, Y_test, verbose=VERBOSE)
print("Test score:", score[0])
print('Test accuracy:', score[1])
# Out:
# 60000 train samples
# 10000 test samples
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_35 (Dense)             (None, 128)               100480
# _________________________________________________________________
# activation_35 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_36 (Dense)             (None, 10)                1290
# _________________________________________________________________
# activation_36 (Activation)   (None, 10)                0
# _________________________________________________________________
# dense_37 (Dense)             (None, 10)                110
# _________________________________________________________________
# activation_37 (Activation)   (None, 10)                0
# =================================================================
# Total params: 101,880
# Trainable params: 101,880
# Non-trainable params: 0
# _________________________________________________________________
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/20
# 48000/48000 [==============================] - 3s 61us/step - loss: 1.7091 - accuracy: 0.5096 - val_loss: 1.0386 - val_accuracy: 0.7514
# Epoch 2/20
# 48000/48000 [==============================] - 3s 53us/step - loss: 0.7749 - accuracy: 0.8007 - val_loss: 0.5710 - val_accuracy: 0.8482
# Epoch 3/20
# 48000/48000 [==============================] - 2s 50us/step - loss: 0.5394 - accuracy: 0.8476 - val_loss: 0.4517 - val_accuracy: 0.8756
# Epoch 4/20
# 48000/48000 [==============================] - 2s 48us/step - loss: 0.4538 - accuracy: 0.8701 - val_loss: 0.3942 - val_accuracy: 0.8905
# Epoch 5/20
# 48000/48000 [==============================] - 2s 49us/step - loss: 0.4035 - accuracy: 0.8848 - val_loss: 0.3567 - val_accuracy: 0.9008
# Epoch 6/20
# 48000/48000 [==============================] - 2s 49us/step - loss: 0.3683 - accuracy: 0.8958 - val_loss: 0.3292 - val_accuracy: 0.9074
# Epoch 7/20
# 48000/48000 [==============================] - 2s 50us/step - loss: 0.3407 - accuracy: 0.9035 - val_loss: 0.3069 - val_accuracy: 0.9127
# Epoch 8/20
# 48000/48000 [==============================] - 2s 51us/step - loss: 0.3183 - accuracy: 0.9095 - val_loss: 0.2891 - val_accuracy: 0.9184
# Epoch 9/20
# 48000/48000 [==============================] - 3s 57us/step - loss: 0.2998 - accuracy: 0.9145 - val_loss: 0.2740 - val_accuracy: 0.9229
# Epoch 10/20
# 48000/48000 [==============================] - 2s 52us/step - loss: 0.2836 - accuracy: 0.9196 - val_loss: 0.2622 - val_accuracy: 0.9259
# Epoch 11/20
# 48000/48000 [==============================] - 3s 56us/step - loss: 0.2693 - accuracy: 0.9238 - val_loss: 0.2499 - val_accuracy: 0.9293
# Epoch 12/20
# 48000/48000 [==============================] - 3s 57us/step - loss: 0.2564 - accuracy: 0.9280 - val_loss: 0.2403 - val_accuracy: 0.9327
# Epoch 13/20
# 48000/48000 [==============================] - 3s 63us/step - loss: 0.2451 - accuracy: 0.9307 - val_loss: 0.2317 - val_accuracy: 0.9351
# Epoch 14/20
# 48000/48000 [==============================] - 2s 51us/step - loss: 0.2349 - accuracy: 0.9341 - val_loss: 0.2224 - val_accuracy: 0.9373
# Epoch 15/20
# 48000/48000 [==============================] - 2s 52us/step - loss: 0.2255 - accuracy: 0.9361 - val_loss: 0.2143 - val_accuracy: 0.9398
# Epoch 16/20
# 48000/48000 [==============================] - 2s 47us/step - loss: 0.2170 - accuracy: 0.9386 - val_loss: 0.2080 - val_accuracy: 0.9417
# Epoch 17/20
# 48000/48000 [==============================] - 2s 51us/step - loss: 0.2092 - accuracy: 0.9407 - val_loss: 0.2013 - val_accuracy: 0.9445
# Epoch 18/20
# 48000/48000 [==============================] - 2s 46us/step - loss: 0.2020 - accuracy: 0.9427 - val_loss: 0.1963 - val_accuracy: 0.9446
# Epoch 19/20
# 48000/48000 [==============================] - 2s 46us/step - loss: 0.1953 - accuracy: 0.9438 - val_loss: 0.1917 - val_accuracy: 0.9480
# Epoch 20/20
# 48000/48000 [==============================] - 2s 52us/step - loss: 0.1892 - accuracy: 0.9457 - val_loss: 0.1863 - val_accuracy: 0.9473
# 10000/10000 [==============================] - 0s 29us/step
# Test score: 0.18953929247111082
# Test accuracy: 0.9437000155448914

# %%
# Three Hidden Layers
from __future__ import print_function
import numpy as np
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers.core import Dense, Activation
from keras.optimizers import SGD
from keras.utils import np_utils
np.random.seed(1671) # for reproducibility
# network and training
NB_EPOCH = 20
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10 # number of outputs = number of digits
OPTIMIZER = SGD() # optimizer, explained later in this chapter
N_HIDDEN = 128
VALIDATION_SPLIT = 0.2 #how much TRAIN is reserved for VALIDATION
# data: shuffled and split between train and test sets
(X_train, y_train), (X_test, y_test) = mnist.load_data()
#X_train is 60000 rows of 28x28 values --> reshaped in 60000 x 784
RESHAPED = 784
#
X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
# normalize
X_train /= 255
X_test /= 255
print (X_train.shape[0], 'train samples')
print (X_test.shape[0], 'test samples')
# convert class vectors to binary class matrices
Y_train = np_utils.to_categorical(y_train, NB_CLASSES)
Y_test = np_utils.to_categorical(y_test, NB_CLASSES)
# M_HIDDEN hidden layers
# 10 outputs
# final stage is softmax
model = Sequential()
model.add(Dense(N_HIDDEN, input_shape=(RESHAPED,)))
model.add(Activation('relu'))
model.add(Dense(NB_CLASSES))
model.add(Activation('relu'))
model.add(Dense(NB_CLASSES))
model.add(Activation('relu'))
model.add(Dense(NB_CLASSES))
model.add(Activation('softmax'))
model.summary()
model.compile(loss='categorical_crossentropy', 
             optimizer=OPTIMIZER,
             metrics=['accuracy'])
history = model.fit(X_train, Y_train,
                   batch_size=BATCH_SIZE, epochs=NB_EPOCH,
                   verbose=VERBOSE, validation_split=VALIDATION_SPLIT)
score = model.evaluate(X_test, Y_test, verbose=VERBOSE)
print("Test score:", score[0])
print('Test accuracy:', score[1])
# Out:
# 60000 train samples
# 10000 test samples
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_38 (Dense)             (None, 128)               100480
# _________________________________________________________________
# activation_38 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_39 (Dense)             (None, 10)                1290
# _________________________________________________________________
# activation_39 (Activation)   (None, 10)                0
# _________________________________________________________________
# dense_40 (Dense)             (None, 10)                110
# _________________________________________________________________
# activation_40 (Activation)   (None, 10)                0
# _________________________________________________________________
# dense_41 (Dense)             (None, 10)                110
# _________________________________________________________________
# activation_41 (Activation)   (None, 10)                0
# =================================================================
# Total params: 101,990
# Trainable params: 101,990
# Non-trainable params: 0
# _________________________________________________________________
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/20
# 48000/48000 [==============================] - 3s 60us/step - loss: 1.9295 - accuracy: 0.3628 - val_loss: 1.4620 - val_accuracy: 0.5647
# Epoch 2/20
# 48000/48000 [==============================] - 2s 51us/step - loss: 1.1131 - accuracy: 0.6654 - val_loss: 0.8193 - val_accuracy: 0.7749
# Epoch 3/20
# 48000/48000 [==============================] - 2s 51us/step - loss: 0.7046 - accuracy: 0.8041 - val_loss: 0.5677 - val_accuracy: 0.8450
# Epoch 4/20
# 48000/48000 [==============================] - 3s 55us/step - loss: 0.5317 - accuracy: 0.8520 - val_loss: 0.4535 - val_accuracy: 0.8753
# Epoch 5/20
# 48000/48000 [==============================] - 3s 56us/step - loss: 0.4432 - accuracy: 0.8763 - val_loss: 0.3914 - val_accuracy: 0.8917
# Epoch 6/20
# 48000/48000 [==============================] - 3s 56us/step - loss: 0.3887 - accuracy: 0.8911 - val_loss: 0.3509 - val_accuracy: 0.9031
# Epoch 7/20
# 48000/48000 [==============================] - 3s 54us/step - loss: 0.3497 - accuracy: 0.9020 - val_loss: 0.3230 - val_accuracy: 0.9101
# Epoch 8/20
# 48000/48000 [==============================] - 3s 52us/step - loss: 0.3188 - accuracy: 0.9110 - val_loss: 0.2958 - val_accuracy: 0.9187
# Epoch 9/20
# 48000/48000 [==============================] - 2s 48us/step - loss: 0.2945 - accuracy: 0.9178 - val_loss: 0.2803 - val_accuracy: 0.9233
# Epoch 10/20
# 48000/48000 [==============================] - 2s 47us/step - loss: 0.2734 - accuracy: 0.9246 - val_loss: 0.2596 - val_accuracy: 0.9267
# Epoch 11/20
# 48000/48000 [==============================] - 3s 52us/step - loss: 0.2555 - accuracy: 0.9293 - val_loss: 0.2449 - val_accuracy: 0.9322
# Epoch 12/20
# 48000/48000 [==============================] - 3s 60us/step - loss: 0.2399 - accuracy: 0.9342 - val_loss: 0.2343 - val_accuracy: 0.9353
# Epoch 13/20
# 48000/48000 [==============================] - 3s 66us/step - loss: 0.2266 - accuracy: 0.9379 - val_loss: 0.2241 - val_accuracy: 0.9370
# Epoch 14/20
# 48000/48000 [==============================] - 3s 53us/step - loss: 0.2150 - accuracy: 0.9406 - val_loss: 0.2148 - val_accuracy: 0.9403
# Epoch 15/20
# 48000/48000 [==============================] - 3s 60us/step - loss: 0.2043 - accuracy: 0.9426 - val_loss: 0.2054 - val_accuracy: 0.9423
# Epoch 16/20
# 48000/48000 [==============================] - 3s 52us/step - loss: 0.1947 - accuracy: 0.9455 - val_loss: 0.1970 - val_accuracy: 0.9460
# Epoch 17/20
# 48000/48000 [==============================] - 2s 48us/step - loss: 0.1855 - accuracy: 0.9483 - val_loss: 0.1873 - val_accuracy: 0.9482
# Epoch 18/20
# 48000/48000 [==============================] - 2s 49us/step - loss: 0.1776 - accuracy: 0.9495 - val_loss: 0.1813 - val_accuracy: 0.9496
# Epoch 19/20
# 48000/48000 [==============================] - 2s 49us/step - loss: 0.1702 - accuracy: 0.9520 - val_loss: 0.1762 - val_accuracy: 0.9507
# Epoch 20/20
# 48000/48000 [==============================] - 3s 52us/step - loss: 0.1636 - accuracy: 0.9539 - val_loss: 0.1695 - val_accuracy: 0.9530
# 10000/10000 [==============================] - 0s 34us/step
# Test score: 0.17509758788496255
# Test accuracy: 0.9510999917984009

# %%
# Five Hidden Layers
from __future__ import print_function
import numpy as np
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers.core import Dense, Activation
from keras.optimizers import SGD
from keras.utils import np_utils
np.random.seed(1671) # for reproducibility
# network and training
NB_EPOCH = 20
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10 # number of outputs = number of digits
OPTIMIZER = SGD() # optimizer, explained later in this chapter
N_HIDDEN = 128
VALIDATION_SPLIT = 0.2 #how much TRAIN is reserved for VALIDATION
# data: shuffled and split between train and test sets
(X_train, y_train), (X_test, y_test) = mnist.load_data()
#X_train is 60000 rows of 28x28 values --> reshaped in 60000 x 784
RESHAPED = 784
#
X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
# normalize
X_train /= 255
X_test /= 255
print (X_train.shape[0], 'train samples')
print (X_test.shape[0], 'test samples')
# convert class vectors to binary class matrices
Y_train = np_utils.to_categorical(y_train, NB_CLASSES)
Y_test = np_utils.to_categorical(y_test, NB_CLASSES)
# M_HIDDEN hidden layers
# 10 outputs
# final stage is softmax
model = Sequential()
model.add(Dense(N_HIDDEN, input_shape=(RESHAPED,)))
model.add(Activation('relu'))
model.add(Dense(NB_CLASSES))
model.add(Activation('relu'))
model.add(Dense(NB_CLASSES))
model.add(Activation('relu'))
model.add(Dense(NB_CLASSES))
model.add(Activation('relu'))
model.add(Dense(NB_CLASSES))
model.add(Activation('relu'))
model.add(Dense(NB_CLASSES))
model.add(Activation('softmax'))
model.summary()
model.compile(loss='categorical_crossentropy', 
             optimizer=OPTIMIZER,
             metrics=['accuracy'])
history = model.fit(X_train, Y_train,
                   batch_size=BATCH_SIZE, epochs=NB_EPOCH,
                   verbose=VERBOSE, validation_split=VALIDATION_SPLIT)
score = model.evaluate(X_test, Y_test, verbose=VERBOSE)
print("Test score:", score[0])
print('Test accuracy:', score[1])
# Out:
# 60000 train samples
# 10000 test samples
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_42 (Dense)             (None, 128)               100480
# _________________________________________________________________
# activation_42 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_43 (Dense)             (None, 10)                1290
# _________________________________________________________________
# activation_43 (Activation)   (None, 10)                0
# _________________________________________________________________
# dense_44 (Dense)             (None, 10)                110
# _________________________________________________________________
# activation_44 (Activation)   (None, 10)                0
# _________________________________________________________________
# dense_45 (Dense)             (None, 10)                110
# _________________________________________________________________
# activation_45 (Activation)   (None, 10)                0
# _________________________________________________________________
# dense_46 (Dense)             (None, 10)                110
# _________________________________________________________________
# activation_46 (Activation)   (None, 10)                0
# _________________________________________________________________
# dense_47 (Dense)             (None, 10)                110
# _________________________________________________________________
# activation_47 (Activation)   (None, 10)                0
# =================================================================
# Total params: 102,210
# Trainable params: 102,210
# Non-trainable params: 0
# _________________________________________________________________
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/20
# 48000/48000 [==============================] - 3s 67us/step - loss: 2.2645 - accuracy: 0.1596 - val_loss: 2.1794 - val_accuracy: 0.2142
# Epoch 2/20
# 48000/48000 [==============================] - 3s 57us/step - loss: 1.9856 - accuracy: 0.3182 - val_loss: 1.7811 - val_accuracy: 0.3988
# Epoch 3/20
# 48000/48000 [==============================] - 2s 52us/step - loss: 1.6135 - accuracy: 0.4128 - val_loss: 1.4855 - val_accuracy: 0.4347
# Epoch 4/20
# 48000/48000 [==============================] - 3s 55us/step - loss: 1.3731 - accuracy: 0.4870 - val_loss: 1.2425 - val_accuracy: 0.5405
# Epoch 5/20
# 48000/48000 [==============================] - 3s 55us/step - loss: 1.1247 - accuracy: 0.6162 - val_loss: 0.9765 - val_accuracy: 0.7218
# Epoch 6/20
# 48000/48000 [==============================] - 3s 70us/step - loss: 0.8346 - accuracy: 0.7763 - val_loss: 0.6693 - val_accuracy: 0.8244
# Epoch 7/20
# 48000/48000 [==============================] - 3s 64us/step - loss: 0.5996 - accuracy: 0.8394 - val_loss: 0.5092 - val_accuracy: 0.8636
# Epoch 8/20
# 48000/48000 [==============================] - 3s 61us/step - loss: 0.4791 - accuracy: 0.8708 - val_loss: 0.4213 - val_accuracy: 0.8836
# Epoch 9/20
# 48000/48000 [==============================] - 3s 53us/step - loss: 0.4086 - accuracy: 0.8904 - val_loss: 0.3658 - val_accuracy: 0.8998
# Epoch 10/20
# 48000/48000 [==============================] - 3s 53us/step - loss: 0.3572 - accuracy: 0.9032 - val_loss: 0.3330 - val_accuracy: 0.9082
# Epoch 11/20
# 48000/48000 [==============================] - 3s 57us/step - loss: 0.3178 - accuracy: 0.9146 - val_loss: 0.2979 - val_accuracy: 0.9186
# Epoch 12/20
# 48000/48000 [==============================] - 3s 61us/step - loss: 0.2868 - accuracy: 0.9225 - val_loss: 0.2735 - val_accuracy: 0.9236
# Epoch 13/20
# 48000/48000 [==============================] - 3s 67us/step - loss: 0.2609 - accuracy: 0.9300 - val_loss: 0.2658 - val_accuracy: 0.9277
# Epoch 14/20
# 48000/48000 [==============================] - 3s 55us/step - loss: 0.2394 - accuracy: 0.9340 - val_loss: 0.2406 - val_accuracy: 0.9334
# Epoch 15/20
# 48000/48000 [==============================] - 3s 55us/step - loss: 0.2203 - accuracy: 0.9386 - val_loss: 0.2450 - val_accuracy: 0.9327
# Epoch 16/20
# 48000/48000 [==============================] - 3s 59us/step - loss: 0.2050 - accuracy: 0.9448 - val_loss: 0.2259 - val_accuracy: 0.9373
# Epoch 17/20
# 48000/48000 [==============================] - 3s 60us/step - loss: 0.1903 - accuracy: 0.9470 - val_loss: 0.2186 - val_accuracy: 0.9399
# Epoch 18/20
# 48000/48000 [==============================] - 3s 52us/step - loss: 0.1787 - accuracy: 0.9510 - val_loss: 0.2030 - val_accuracy: 0.9453
# Epoch 19/20
# 48000/48000 [==============================] - 2s 48us/step - loss: 0.1662 - accuracy: 0.9538 - val_loss: 0.2007 - val_accuracy: 0.9457
# Epoch 20/20
# 48000/48000 [==============================] - 3s 54us/step - loss: 0.1578 - accuracy: 0.9570 - val_loss: 0.1907 - val_accuracy: 0.9483
# 10000/10000 [==============================] - 0s 30us/step
# Test score: 0.18540319982618095
# Test accuracy: 0.9469000101089478

# %% [markdown]
# Through my testing I found that:
#
# Two Hidden Layers
# Test score: 0.18953929247111082
# Test accuracy: 0.9437000155448914
#
# Three Hidden Layers
# Test score: 0.17509758788496255
# Test accuracy: 0.9510999917984009
#
# Five Hidden Layers
# Test score: 0.18540319982618095
# Test accuracy: 0.9469000101089478
#
#
# Between Two and Three Hidden Layers (2-3) 2 being better for test Scores, but was worse for overall Test Accuracy.
# Test Score Difference = 0.01444 (Better)
# Test Accuracy Difference = -0.00739 (Worse)
#
# Between Two and Five Hidden Layers (2-5) 2 being better for Test Scores, but was worse for overall Test Accuracy.
# Test Score Difference = 0.00413 (Better)
# Test Accuracy Difference = -0.0032 (Worse)
#
# Between Three and Five Hidden Layers (3-5) 3 being worse for Test Scores, but had better overall Test Accuracy.
# Test Score Difference = -0.01031 (Worse)
# Test Accuracy Difference = 0.00419 (Better)
#
# From these numbers I got, I would find that having more hidden layers could contribute to having a worse overall Test Score Difference while also increasing the overall Test Accuracy Difference as shown by my three examples (Where I find 3 to be a bit of an outlier but still proves my overall point).
